# %%
if 10<20:
    print(10+20)
# Out:
# 30

# %%
a=10
b=20
if a<b:
    print(a+b)
print("Done")
# Out:
# 30
# Done

# %%
a=10
b=20
if a>b:
    print(a+b)
print("Done")
# Out:
# Done

# %%
x=100
y=50
if x<y:
    print(x+y)
else:
    print(x-y)
print("Done")
# Out:
# 50
# Done

# %%
x=100
y=50
if x>y:
    print(x+y)
else:
    print(x-y)
print("Done")
# Out:
# 150
# Done

# %%
Total=200
Passing_Marks=75
Student_Marks=100
if Passing_Marks>Student_Marks:
    print("Student Is Fail")
else:
    print("Student Is Pass")
print("Congratulations")
# Out:
# Student Is Pass
# Congratulations

# %%
Age=int(input("Enter Your Age : "))
if Age>=18:
        print("You are the Eligible For The Voting And Your Age is :",Age)
else:
        print("You are not Eligible for The Voting And Your Age is :",Age)
# Out:
# Enter Your Age :  18
# You are the Eligible For The Voting And Your Age is : 18

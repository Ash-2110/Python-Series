# %% [markdown]
# wht is pandas?
# -pandas is a python library which is used for the DA,DS and Data Manipulation.

# %% [markdown]
# how to import a dataframe - using the path and using the name?
# -import pandas as pd  # import the lybrary
#
# -df = pd.read_csv("file_name.csv")
# -df = pd.read_csv("give the path of that file.csv")

# %% [markdown]
# #ACCESSING THE DATA

# %% [markdown]
# for the selecting the column.
# -df["column_name")

# %% [markdown]
# select the 1st or last N rows of a DF?
# -df.head(1)
# -df.tail(1)

# %% [markdown]
# select the multiple columns in df
# -df[["column_name","colunm_name"]]

# %% [markdown]
# filter a df based on condition  -   NO

# %% [markdown]
# select the a row by its index in df? - NO

# %% [markdown]
# find the unique value of numerical data? - NO

# %% [markdown]
# calculate.
# min.
# df["column_name"].min()
# max.
# df["column_name"].max()
# mean.
# df["column_name"].mean()
# sum.
# df["column_name"].sum()

# %% [markdown]
# #MANIPULATING THE DATA

# %% [markdown]
# add new column in the exiting the df
# df["column_name"]=["data"]

# %% [markdown]
# drop a column from a df
# -df.drop("column_name")

# %% [markdown]
# selct the row where the age is greater than 30
# -df[df["age"] > 30]

# %% [markdown]
# #merging and joining data

# %% [markdown]
# merge two data frame based on column?
# df3=pd.concate(df1,df2)

# %% [markdown]
# merge two data frame based on id?
# df3=pd.concate(df1,df2)

# %% [markdown]
# #expoting the data:

# %% [markdown]
# save the df to csv file?
# -NO

# %% [markdown]
# read the df from csv file
# df=pd.read_csv("file_name.csv")

# %% [markdown]
# adv and dis-adv of the pandas
# - adv:-
# easy to handle data.
# fast at the exicution.
# support the large datafile or dataset
# - dis-adv:-
# for exicution required the high memory storage

# %% [markdown]
# #Check Positive or Negative
# #Write a program to check if a number is positive, negative, or zero.

# %%
num=int(input("Enter the numbers for checking the +ve,-ve,0 : "))
if num>0:
    print(num)
# Out:
# Enter the numbers for checking the +ve,-ve,0 :  1
# 1

# %% [markdown]
# **What is Python?**

# %% [markdown]
# The Python is High level and interpreter Programming language

# %% [markdown]
# **Who developed Python, and when was it first released?**

# %% [markdown]
# In the 1991

# %% [markdown]
# **What are some key features of Python?**

# %% [markdown]
# -It is High Level and Interpreter Programming language.
# -It Content The Multiple Libraries To Perform The Code.

# %% [markdown]
# **What are the disadvantages of using Python?**

# %% [markdown]
# At the time of exicuting the program it requied the more memory storage.
# in this programming language have more indentation error at the run time means it is case sensetive

# %% [markdown]
# **Why is Python considered Best compared to other programming languages like C++ or
# Java?**

# %% [markdown]
# 1- It is Simple understanding Programming Language for non-technical person as compiared to java and c++.
# 2- The syntax of this language is like simple english words as compiared to the java and c++.
# 3-abd it have the more libraries to perform the high level task like Machin learning,Data Science,AI

# %% [markdown]
# **What is a variable in Python?**

# %% [markdown]
# Varial is the container to store the Data values in the python

# %% [markdown]
# **How do you check the type of variable in Python?**

# %% [markdown]
# To checking the variable in The Python By using the "x=" or "x" like this

# %% [markdown]
# **What is a comment in Python?**

# %% [markdown]
# comments is simple sentence It Used the for the understand the program for any user or programmer

# %% [markdown]
# **How do you write single-line and multi-line comments in Python?**

# %% [markdown]
# #- is like this the Single line comment in the python
# """ is like this we used the multiple line comments in the python"""

# %% [markdown]
# **Why are comments important in programming?**

# %% [markdown]
# comments is simple sentence It Used the for the understand the program for any user or programmer

# %% [markdown]
# **What are the common data types in Python?**

# %% [markdown]
# Numerical,Dictionary,Set(Sting, Integer, Float)

# %% [markdown]
# **What is the difference between mutable and immutable data types?**

# %% [markdown]
# mutable-it is a type where we can modify the data in the data type like list,dict ect..
# immutable-it is a type where we can not be modify the data in the data type like tuppel...

# %% [markdown]
# **Explain the following data types with examples:**

# %% [markdown]
# 1.int- it is data type where we can store in interger data like x=4.
# 2.float- it is data type where we can store in float type data in the point decimal type like x=4.01 or x=4.00.
# 3.str- it is data type where we can store in string data type,it can store all type if data like (4,5.2,"fgfgdfg").
# 4.list- it is data type where we can store in list type data which we can modify like list=[4,5,8,].
# 5.tuple- it is data type where we can store in the tuple type like tuple.
# 6.dict- it is data type where we can store in the dictionary type with key:value pair like dict={ "name":"ashutosh","age":21}

# %% [markdown]
# **What is type casting in Python?**

# %% [markdown]
# it method to change the data type in the python programing and it have the 2 types -automation,-manual

# %% [markdown]
# **How do you perform Automatic and Manual type casting?**

# %% [markdown]
# Manual type--
# x=4  # it is in the integer
# f=str(x) #now it is in the string type

# %% [markdown]
# **Give examples of type conversion using int(), to float().**

# %% [markdown]
# x=4 #it is in the integer
# x=float(x) #it is in the float

# %% [markdown]
# **What are operators in Python?**

# %% [markdown]
# Operator it is method to perform the numerical operation on the value

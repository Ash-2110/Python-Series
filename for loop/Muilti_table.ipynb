# %%
a = int(input("Enter the table number: "))
b = int(input("Enter the last multiplier: "))
c=int(input("Enter the number where you want the break: "))
for i in range(1, b + 1):
    total=a*i
    print(total)
    if total==c:
        break
# Out:
# Enter the table number:  5
# Enter the last multiplier:  50
# Enter the number where you want the break:  30
# 5
# 10
# 15
# 20
# 25
# 30

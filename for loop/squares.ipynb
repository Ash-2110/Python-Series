# %%
N = int(input("Enter N: "))

for i in range(1, N + 1):
    print(i, "==", i * i)
# Out:
# Enter N:  10
# 1 == 1
# 2 == 4
# 3 == 9
# 4 == 16
# 5 == 25
# 6 == 36
# 7 == 49
# 8 == 64
# 9 == 81
# 10 == 100

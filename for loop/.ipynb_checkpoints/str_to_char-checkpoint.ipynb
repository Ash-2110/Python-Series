# %%
s = "Python"
for ch in s:
    print(ch)
# Out:
# P
# y
# t
# h
# o
# n

# %%
name="ashutosh","rajendra","jagdale"
for i in range(len(name)):
    print(name[i])
# Out:
# ashutosh
# rajendra
# jagdale

# %%
fruits=["apple","cherry","kiwi","orange"]
for f in fruits:
    print(f)
    if f == "kiwi":
        break
# Out:
# apple
# cherry
# kiwi

# %%
fruits=["apple","cherry","kiwi","orange"]
for f in fruits:
    print(f)
    if f == "kiwi":
        continue
# Out:
# apple
# cherry
# kiwi
# orange

# %%
name=["suresh","mahesh","ashutosh","jagdale","ganesh"]
for i in name:
    print(i)
else:
    print("Above are the topper student")
# Out:
# suresh
# mahesh
# ashutosh
# jagdale
# ganesh
# Above are the topper student

# %%
for n in range(10):
    if n == 5:
# Out:
#   Cell In[5], line 3
#
#     ^
# _IncompleteInputError: incomplete input

# %%
for n in range(10):
    if n == 5:
       pass

# %%
print("MENU\n1.ADDITION\n2.SUBSTRACTION\n3.MULTIPLICATION\n4.DIVISION")
a=int(input("Enter MENU number"))
b=int(input("Enter 1st number"))
c=int(input("Enter 2nd number"))
if a == 1:
    print(f"ADDITION OF {b} AND {c} IS :{b+c}")
elif a== 2:
    print(f"SUBSTRACTION OF {b} AND {c} IS :{b-c}")
elif a == 3:
    print(f"MULTIPLICATION OF {b} AND {c} IS :{b*c}")
else:
    print(f"DIVISION OF {b} AND {c} IS :{b/c}")
# Out:
# MENU
# 1.ADDITION
# 2.SUBSTRACTION
# 3.MULTIPLICATION
# 4.DIVISION
# Enter MENU number 4
# Enter 1st number 56
# Enter 2nd number 2
# DIVISION OF 56 AND 2 IS :28.0

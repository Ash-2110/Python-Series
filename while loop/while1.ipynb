# %%
count=0
while count<3:
    print("Data Science")
    count=count+1
# Out:
# Data Science
# Data Science
# Data Science

# %%
a=10
b=12
while(a<b):
    print("hello")
    b=b-1
# Out:
# hello
# hello

# %%
a=10
while(a<15):
    print("hi")
    a=a+2
else:
    print("bye")
# Out:
# hi
# hi
# hi
# bye

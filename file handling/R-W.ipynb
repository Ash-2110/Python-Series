# %%
f=open("Example.txt","w")
f.write("ashutosh rajendra jagdale.\n")
f.close()
print("File created successfully!")
# Out:
# File created successfully!

# %%
pwd
# Out:
# 'D:\\Python-Series\\file handling'

# %%
f=open("Example.txt","r")
content = f.read()
print("File Content : \n",content)
f.close()
# Out:
# File Content :
#  ashutosh rajendra jagdale.
